# %%
import torch
import torch.nn as nn

# %% [markdown]
# ## Padding — saving border information
# Without Padding , CNNs shrink images too fast and lose the edge info.

# %%
x = torch.randn(1, 1, 5, 5)

conv = nn.Conv2d(1, 1, kernel_size=3, padding=1)

y = conv(x)

print(y.shape)
