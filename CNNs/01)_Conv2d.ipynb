# %% [markdown]
# # CNNs

# %%
import torch
import torch.nn as nn

# %%
x = torch.randn(1, 1, 5, 5)

conv = nn.Conv2d(1,2,kernel_size = 3)

y = conv(x)

print(x.shape)
print(y.shape)
# Out:
# torch.Size([1, 1, 5, 5])
# torch.Size([1, 2, 3, 3])

# %% [markdown]
# ## Input
# CNN always expect 4D input <br>
# `(batch, channels, height, width)`
#
# ## Convolution Layer
# ```python
# conv = nn.Conv2d(1, 2, kernel_size=3)
# ```
# - 🎯 Creates a convolution layer
#
# | Parameter | Meaning         | Why                  |
# | --------- | --------------- | -------------------- |
# | `1`       | Input channels  | Matches `x`          |
# | `2`       | Output channels | Number of filters    |
# | `3`       | Kernel size     | 3x3 feature detector |
#
# Each filter learns patterns like edges, curves, textures
