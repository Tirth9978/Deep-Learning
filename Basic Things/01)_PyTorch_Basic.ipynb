# %%
import torch
x = torch.tensor([1.0, 2.0, 3.0])
print(x)
print(x.dtype)
print(x.shape)

# 2D
y = torch.tensor([[1.0, 2.0],
                  [3.0, 4.0]])

a = torch.tensor([5.0, 10.0])
b = torch.tensor([2.0, 4.0])

print(a + b)
print(a * b)
